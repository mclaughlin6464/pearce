# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import numpy as np

# %%
fname = 'proj_bias_hist_idx_000_box_000.npy'

# %%
im_list = np.load(fname)
print im_list.shape
# Out:
# (2025, 16, 16, 1)

# %% [raw]
# for idx, im in enumerate(im_list):
#     #if idx > 0:
#     #    break
#     implt = plt.imshow(np.log10(np.abs(im[:, :, 0])+1e-6), vmin = -6, vmax = 6)
#     plt.colorbar(implt)
#     plt.show()

# %%
fname2 = 'full_proj_box_000.npy'#'full_bias_hist_idx_000_box_000.npy'

# %%
particle_box = np.load(fname2)

# %%
particle_box.shape
# Out:
# (720, 720, 1)

# %%
np.max(particle_box), np.min(particle_box)
# Out:
# (9936.0, 0.0)

# %%
particle_box.shape
# Out:
# (720, 720, 1)

# %% [raw]
# for idx, im in enumerate(particle_box):
#     #if idx > 0:
#     #    break
#     implt = plt.imshow(np.log10(im[:, :, 0]+1), vmin = 0, vmax = 4)
#     plt.colorbar(implt)
#     plt.show()

# %%
from matplotlib.colors import LogNorm
#norm = LogNorm(vmin = particle_box.min(), vmax = particle_box.max())

# %%
img = plt.imshow(particle_box[:,:,0] - particle_box.min() + 1e-6, norm = LogNorm(vmin = 1e-6, vmax = particle_box.max()-particle_box.min()))
plt.colorbar(img)
